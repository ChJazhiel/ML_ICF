# %% [markdown]
# # Importar utilidades

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Cargar el diccionario con el dataset de las partículas y sus labels

# %%
dict_data = np.load('nbody_data.npz')
test_flags  = dict_data['test_flags']
test_hosts  = dict_data['test_hosts']
test_mass   = dict_data['test_mass']
test_labels = dict_data['test_labels']
test_input  = dict_data['test_input']
#test_snid   = dict_data['test_snid']
#test_labels = dict_data['test_labels']
print(test_mass)
print(len(test_labels))
# Out:
# [-1.00000000e+00 -1.00000000e+00 -1.00000000e+00 ...  3.43922706e+12
#   3.73214214e+12 -1.00000000e+00]
# 50000

# %% [markdown]
# # Visualizar la distribución del dataset, seleccionando los label 0 y 1

# %%
dr1 = pd.DataFrame(test_input[0], columns = ['dr1'])
dr2 = pd.DataFrame(test_input[1], columns = ['dr2'])
dr3 = pd.DataFrame(test_input[2], columns = ['dr3'])
dr4 = pd.DataFrame(test_input[3], columns = ['dr4'])
dr5 = pd.DataFrame(test_input[4], columns = ['dr5'])
dr6 = pd.DataFrame(test_input[5], columns = ['dr6'])
dr7 = pd.DataFrame(test_input[6], columns = ['dr7'])
dr8 = pd.DataFrame(test_input[7], columns = ['dr8'])
dr9 = pd.DataFrame(test_input[8], columns = ['dr9'])
dr10 = pd.DataFrame(test_input[9], columns = ['dr10'])
lbl = pd.DataFrame(test_labels, columns =['labels'])

df = pd.concat([dr1, dr2, dr3, dr4, dr5, dr6, dr7, dr8, dr9, dr10, lbl], axis=1, ignore_index=False, sort=False)
df
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 0     -0.072444 -0.061586 -0.051498 -0.043164 -0.042943 -0.038666 -0.022006
# 1     -0.023196 -0.028977 -0.032844 -0.035750 -0.030538 -0.030028 -0.030826
# 2     -0.064928 -0.051309 -0.038937 -0.026395 -0.018813 -0.010008 -0.011911
# 3     -0.007017 -0.014499 -0.016319 -0.015009 -0.017215 -0.018528 -0.012800
# 4      0.041678  0.027833  0.021245  0.021244  0.025114  0.027951  0.015306
# 5      0.011900  0.017608  0.018426  0.037043  0.044348  0.034767  0.024490
# 6      0.053402  0.052521  0.061032  0.064198  0.064688  0.048487  0.040523
# 7     -0.064056 -0.054995 -0.056007 -0.059019 -0.058715 -0.052802 -0.046752
# 8      0.035668  0.042164  0.039746  0.025888  0.021406  0.029333  0.027130
# 9      0.132181  0.110570  0.091219  0.063228  0.043150  0.033300  0.027070
# 10    -0.061467 -0.058172 -0.054846 -0.067383 -0.068216 -0.059909 -0.049182
# ...

# %%
import seaborn as sns
#import seaborn as sns
# %matplotlib inline
#%matplotlib qt
#matplotlib notebook

df1_0 = df[df.labels == 0]
df1_1 = df[df.labels == 1]

sns.distplot(df1_0['dr1'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr1'], kde=True, hist=False, label='label = 1')
plt.axvline(0.012)
plt.legend()
sns.set(style="darkgrid")
plt.show()


sns.distplot(df1_0['dr2'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr2'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr3'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr3'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr4'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr4'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr5'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr5'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr6'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr6'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr7'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr7'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr8'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr8'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr9'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr9'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr10'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr10'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

# %% [markdown]
# # Seleccionar arreglos para escalas $\delta r_{1}, ... , \delta r_{10}$, que serán arreglos de 50000x1

# %%
dr1 = pd.DataFrame(test_input[0], columns = ['dr1'])
dr2 = pd.DataFrame(test_input[1], columns = ['dr2'])
dr3 = pd.DataFrame(test_input[2], columns = ['dr3'])
dr4 = pd.DataFrame(test_input[3], columns = ['dr4'])
dr5 = pd.DataFrame(test_input[4], columns = ['dr5'])
dr6 = pd.DataFrame(test_input[5], columns = ['dr6'])
dr7 = pd.DataFrame(test_input[6], columns = ['dr7'])
dr8 = pd.DataFrame(test_input[7], columns = ['dr8'])
dr9 = pd.DataFrame(test_input[8], columns = ['dr9'])
dr10 = pd.DataFrame(test_input[9], columns = ['dr10'])
lbl = pd.DataFrame(test_labels, columns = ['labels'])


dr1_z1 = pd.concat([dr1, lbl], axis=1, ignore_index=False, sort=False)
dr2_z1 = pd.concat([dr2, lbl], axis=1, ignore_index=False, sort=False)
dr3_z1 = pd.concat([dr3, lbl], axis=1, ignore_index=False, sort=False)
dr4_z1 = pd.concat([dr4, lbl], axis=1, ignore_index=False, sort=False)
dr5_z1 = pd.concat([dr5, lbl], axis=1, ignore_index=False, sort=False)
dr6_z1 = pd.concat([dr6, lbl], axis=1, ignore_index=False, sort=False)
dr7_z1 = pd.concat([dr7, lbl], axis=1, ignore_index=False, sort=False)
dr8_z1 = pd.concat([dr8, lbl], axis=1, ignore_index=False, sort=False)
dr9_z1 = pd.concat([dr9, lbl], axis=1, ignore_index=False, sort=False)
dr10_z1 = pd.concat([dr10, lbl], axis=1, ignore_index=False, sort=False)

# %%
dr10_z1
# Out:
#            dr10  labels
# 0     -0.008389       0
# 1     -0.024011       0
# 2      0.001661       0
# 3     -0.009015       0
# 4     -0.003758       0
# 5      0.014670       1
# 6      0.017753       1
# 7     -0.013380       0
# 8      0.004234       1
# 9     -0.004146       1
# 10    -0.014837       0
# 11     0.017919       1
# 12    -0.000392       1
# 13     0.003438       1
# 14    -0.012127       0
# 15     0.034278       1
# 16     0.009815       0
# 17    -0.013910       0
# 18    -0.006947       0
# 19     0.019783       1
# 20     0.015371       0
# 21    -0.011585       0
# 22    -0.011208       0
# 23     0.019116       0
# 24    -0.003945       0
# 25    -0.010830       1
# 26    -0.002495       0
# 27     0.012743       0
# 28     0.008278       0
# 29    -0.002057       0
# ...         ...     ...
# 49970  0.019841       0
# 49971 -0.015155       0
# 49972  0.023007       1
# 49973 -0.025166       0
# 49974  0.009119       1
# 49975 -0.002621       0
# ...

# %% [markdown]
# ## Seleccionar un training set para  escalas $\delta r_{1}, ... \delta r_{10}$ de manera aleatoria

# %%
ord_dr1 = dr1_z1.sort_values(by='labels')
ord_dr2 = dr2_z1.sort_values(by='labels')
ord_dr3 = dr3_z1.sort_values(by='labels')
ord_dr4 = dr4_z1.sort_values(by='labels')
ord_dr5 = dr5_z1.sort_values(by='labels')
ord_dr6 = dr6_z1.sort_values(by='labels')
ord_dr7 = dr7_z1.sort_values(by='labels')
ord_dr8 = dr8_z1.sort_values(by='labels')
ord_dr9 = dr9_z1.sort_values(by='labels')
ord_dr10 = dr10_z1.sort_values(by='labels')

# %% [markdown]
# ## Seleccionar de manera aleatoria los elementos para el training set de $\delta r_{1}, ... ,\delta r_{10}$

# %%
train_zeros_dr1 = ord_dr1.head(32456).sample(12000)
train_unos_dr1  = ord_dr1.tail(17544).sample(12000)
train_zeros_dr2 = ord_dr2.head(32456).sample(12000)
train_unos_dr2  = ord_dr2.tail(17544).sample(12000)
train_zeros_dr3 = ord_dr3.head(32456).sample(12000)
train_unos_dr3  = ord_dr3.tail(17544).sample(12000)
train_zeros_dr4 = ord_dr4.head(32456).sample(12000)
train_unos_dr4  = ord_dr4.tail(17544).sample(12000)
train_zeros_dr5 = ord_dr5.head(32456).sample(12000)
train_unos_dr5  = ord_dr5.tail(17544).sample(12000)
train_zeros_dr6 = ord_dr6.head(32456).sample(12000)
train_unos_dr6  = ord_dr6.tail(17544).sample(12000)
train_zeros_dr7 = ord_dr7.head(32456).sample(12000)
train_unos_dr7  = ord_dr7.tail(17544).sample(12000)
train_zeros_dr8 = ord_dr8.head(32456).sample(12000)
train_unos_dr8  = ord_dr8.tail(17544).sample(12000)
train_zeros_dr9 = ord_dr9.head(32456).sample(12000)
train_unos_dr9  = ord_dr9.tail(17544).sample(12000)
train_zeros_dr10 = ord_dr10.head(32456).sample(12000)
train_unos_dr10  = ord_dr10.tail(17544).sample(12000)

# %%
df1_0 = train_zeros_dr1[train_zeros_dr1.labels == 0]
df1_1 = train_unos_dr1[train_unos_dr1.labels == 1]

sns.distplot(df1_0['dr1'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr1'], kde=True, hist=False, label='label = 1')
#plt.axvline(0.012)
plt.legend()
sns.set(style="darkgrid")
plt.show()

# %% [markdown]
# ## Seleccionar de manera aleatoria el test set de $\delta r_{1},...,\delta r_{10}$

# %%
test_zeros_dr1 = ord_dr1.head(32456).sample(5000)
test_unos_dr1  = ord_dr1.tail(17544).sample(5000)
test_zeros_dr2 = ord_dr2.head(32456).sample(5000)
test_unos_dr2  = ord_dr2.tail(17544).sample(5000)
test_zeros_dr3 = ord_dr3.head(32456).sample(5000)
test_unos_dr3  = ord_dr3.tail(17544).sample(5000)
test_zeros_dr4 = ord_dr4.head(32456).sample(5000)
test_unos_dr4  = ord_dr4.tail(17544).sample(5000)
test_zeros_dr5 = ord_dr5.head(32456).sample(5000)
test_unos_dr5  = ord_dr5.tail(17544).sample(5000)
test_zeros_dr6 = ord_dr6.head(32456).sample(5000)
test_unos_dr6  = ord_dr6.tail(17544).sample(5000)
test_zeros_dr7 = ord_dr7.head(32456).sample(5000)
test_unos_dr7  = ord_dr7.tail(17544).sample(5000)
test_zeros_dr8 = ord_dr8.head(32456).sample(5000)
test_unos_dr8  = ord_dr8.tail(17544).sample(5000)
test_zeros_dr9 = ord_dr9.head(32456).sample(5000)
test_unos_dr9  = ord_dr9.tail(17544).sample(5000)
test_zeros_dr10 = ord_dr10.head(32456).sample(5000)
test_unos_dr10  = ord_dr10.tail(17544).sample(5000)

# %%
df1_0 = test_zeros_dr1[test_zeros_dr1.labels == 0]
df1_1 = test_unos_dr1[test_unos_dr1.labels == 1]

sns.distplot(df1_0['dr1'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr1'], kde=True, hist=False, label='label = 1')
plt.axvline(0.012)
plt.legend()
sns.set(style="darkgrid")

plt.show()

# %% [markdown]
# ## Juntar Training set $\delta r_{1}, ... , \delta r_{10}$
#
# ### Concatenar une los datasets de manera ordenada

# %%
train_dr1 = pd.concat([train_zeros_dr1, train_unos_dr1])
train_dr2 = pd.concat([train_zeros_dr2, train_unos_dr2])
train_dr3 = pd.concat([train_zeros_dr3, train_unos_dr3])
train_dr4 = pd.concat([train_zeros_dr4, train_unos_dr4])
train_dr5 = pd.concat([train_zeros_dr5, train_unos_dr5])
train_dr6 = pd.concat([train_zeros_dr6, train_unos_dr6])
train_dr7 = pd.concat([train_zeros_dr7, train_unos_dr7])
train_dr8 = pd.concat([train_zeros_dr8, train_unos_dr8])
train_dr9 = pd.concat([train_zeros_dr9, train_unos_dr9])
train_dr10 = pd.concat([train_zeros_dr10, train_unos_dr10])

# %%
from sklearn.utils import shuffle

# %%
joint_train_set_dr1 = train_dr1.to_numpy()
joint_train_set_dr2 = train_dr2.to_numpy()
joint_train_set_dr3 = train_dr3.to_numpy()
joint_train_set_dr4 = train_dr4.to_numpy()
joint_train_set_dr5 = train_dr5.to_numpy()
joint_train_set_dr6 = train_dr6.to_numpy()
joint_train_set_dr7 = train_dr7.to_numpy()
joint_train_set_dr8 = train_dr8.to_numpy()
joint_train_set_dr9 = train_dr9.to_numpy()
joint_train_set_dr10 = train_dr10.to_numpy()

# %% [markdown]
# ### Efectuamos un shuffle
# Random permutation solo cambia las posiciones de las filas, no sus valores individuales, en un problema de clasificación como este eso es muy valioso

# %%
shuffle_train_dr1 = np.random.permutation(joint_train_set_dr1)
shuffle_train_dr2 = np.random.permutation(joint_train_set_dr2)
shuffle_train_dr3 = np.random.permutation(joint_train_set_dr3)
shuffle_train_dr4 = np.random.permutation(joint_train_set_dr4)
shuffle_train_dr5 = np.random.permutation(joint_train_set_dr5)
shuffle_train_dr6 = np.random.permutation(joint_train_set_dr6)
shuffle_train_dr7 = np.random.permutation(joint_train_set_dr7)
shuffle_train_dr8 = np.random.permutation(joint_train_set_dr8)
shuffle_train_dr9 = np.random.permutation(joint_train_set_dr9)
shuffle_train_dr10 = np.random.permutation(joint_train_set_dr10)

# %% [markdown]
# ## Juntamos testing set

# %%
test_dr1 = pd.concat([test_zeros_dr1, test_unos_dr1])
test_dr2 = pd.concat([test_zeros_dr2, test_unos_dr2])
test_dr3 = pd.concat([test_zeros_dr3, test_unos_dr3])
test_dr4 = pd.concat([test_zeros_dr4, test_unos_dr4])
test_dr5 = pd.concat([test_zeros_dr5, test_unos_dr5])
test_dr6 = pd.concat([test_zeros_dr6, test_unos_dr6])
test_dr7 = pd.concat([test_zeros_dr7, test_unos_dr7])
test_dr8 = pd.concat([test_zeros_dr8, test_unos_dr8])
test_dr9 = pd.concat([test_zeros_dr9, test_unos_dr9])
test_dr10 = pd.concat([test_zeros_dr10, test_unos_dr10])

# %%
joint_test_set_dr1 = test_dr1.to_numpy()
joint_test_set_dr2 = test_dr2.to_numpy()
joint_test_set_dr3 = test_dr3.to_numpy()
joint_test_set_dr4 = test_dr4.to_numpy()
joint_test_set_dr5 = test_dr5.to_numpy()
joint_test_set_dr6 = test_dr6.to_numpy()
joint_test_set_dr7 = test_dr7.to_numpy()
joint_test_set_dr8 = test_dr8.to_numpy()
joint_test_set_dr9 = test_dr9.to_numpy()
joint_test_set_dr10 = test_dr10.to_numpy()

# %%
shuffle_test_dr1 = np.random.permutation(joint_test_set_dr1)
shuffle_test_dr2 = np.random.permutation(joint_test_set_dr2)
shuffle_test_dr3 = np.random.permutation(joint_test_set_dr3)
shuffle_test_dr4 = np.random.permutation(joint_test_set_dr4)
shuffle_test_dr5 = np.random.permutation(joint_test_set_dr5)
shuffle_test_dr6 = np.random.permutation(joint_test_set_dr6)
shuffle_test_dr7 = np.random.permutation(joint_test_set_dr7)
shuffle_test_dr8 = np.random.permutation(joint_test_set_dr8)
shuffle_test_dr9 = np.random.permutation(joint_test_set_dr9)
shuffle_test_dr10 = np.random.permutation(joint_test_set_dr10)

# %% [markdown]
# # Definimos la función que se encarga de calcular la entropía de Shannon

# %%
from math import *
def calcShannonEntropy(dataSet):
    numEntries = len(dataSet)
    labelCounts = {}
    for featVec in dataSet: #the number of unique elements and their occurence
        currentLabel = featVec[-1]
        if currentLabel not in labelCounts.keys(): labelCounts[currentLabel] = 0
        labelCounts[currentLabel] += 1
    shannonEnt = 0.0
    for key in labelCounts:
            prob = float(labelCounts[key])/numEntries
            shannonEnt -= prob * log(prob,2) # log base 2
    return shannonEnt

# %%
#print(min(dr1_z1['dr1']))
#print(max(dr1_z1['dr1']))
#print(min(dr2_z1['dr2']))
#print(max(dr2_z1['dr2']))
#print(min(dr3_z1['dr3']))
#print(max(dr3_z1['dr3']))
#print(min(dr4_z1['dr4']))
#print(max(dr4_z1['dr4']))
#print(min(dr5_z1['dr5']))
#print(max(dr5_z1['dr5']))
#print(min(dr6_z1['dr6']))
#print(max(dr6_z1['dr6']))
#print(min(dr7_z1['dr7']))
#print(max(dr7_z1['dr7']))
#print(min(dr8_z1['dr8']))
#print(max(dr8_z1['dr8']))
#print(min(dr9_z1['dr9']))
#print(max(dr9_z1['dr9']))
print(min(dr10_z1['dr10']))
print(max(dr10_z1['dr10']))
# Out:
# -0.0578908696771
# 0.0588469430804

# %% [markdown]
# ## Creamos un arreglo de 100 bins que está entre los valores minimos y maximos de $\delta r_{1}$

# %%
z1 = np.linspace(-0.227062806487, 0.325069725513, 100)
z2 = np.linspace(-0.194014117122, 0.28170633316, 100)
z3 = np.linspace(-0.173785328865, 0.253833144903, 100)
z4 = np.linspace(-0.159017980099, 0.205019816756, 100)
z5 = np.linspace(-0.138782143593, 0.166183665395, 100)
z6 = np.linspace(-0.11502161622, 0.145021170378, 100)
z7 = np.linspace(-0.10073082149, 0.121186845005, 100)
z8 = np.linspace(-0.0848282277584, 0.0974952429533, 100)
z9 = np.linspace(-0.0694508254528, 0.0724674388766, 100)
z10 = np.linspace(-0.0578908696771, 0.0588469430804, 100)

print(z1)
# Out:
# [-0.22706281 -0.22148571 -0.21590861 -0.21033152 -0.20475442 -0.19917733
#  -0.19360023 -0.18802313 -0.18244604 -0.17686894 -0.17129184 -0.16571475
#  -0.16013765 -0.15456055 -0.14898346 -0.14340636 -0.13782927 -0.13225217
#  -0.12667507 -0.12109798 -0.11552088 -0.10994378 -0.10436669 -0.09878959
#  -0.0932125  -0.0876354  -0.0820583  -0.07648121 -0.07090411 -0.06532701
#  -0.05974992 -0.05417282 -0.04859573 -0.04301863 -0.03744153 -0.03186444
#  -0.02628734 -0.02071024 -0.01513315 -0.00955605 -0.00397896  0.00159814
#   0.00717524  0.01275233  0.01832943  0.02390653  0.02948362  0.03506072
#   0.04063782  0.04621491  0.05179201  0.0573691   0.0629462   0.0685233
#   0.07410039  0.07967749  0.08525459  0.09083168  0.09640878  0.10198587
#   0.10756297  0.11314007  0.11871716  0.12429426  0.12987136  0.13544845
#   0.14102555  0.14660264  0.15217974  0.15775684  0.16333393  0.16891103
#   0.17448813  0.18006522  0.18564232  0.19121941  0.19679651  0.20237361
# ...

# %% [markdown]
# ###  Creamos un dataset nuevo para cada partición y se calcula su entropía

# %%
#p_i, p_d = [[]]*100, [[]]*100
dr1_i, dr1_d = [[]]*100, [[]]*100
dr2_i, dr2_d = [[]]*100, [[]]*100
dr3_i, dr3_d = [[]]*100, [[]]*100
dr4_i, dr4_d = [[]]*100, [[]]*100
dr5_i, dr5_d = [[]]*100, [[]]*100
dr6_i, dr6_d = [[]]*100, [[]]*100
dr7_i, dr7_d = [[]]*100, [[]]*100
dr8_i, dr8_d = [[]]*100, [[]]*100
dr9_i, dr9_d = [[]]*100, [[]]*100
dr10_i, dr10_d = [[]]*100, [[]]*100
for j in range(100):
    #p_i[j] = shuffle_train_dr1[np.where(shuffle_train_dr1[:,0]<=z1[j])]
    #p_d[j] = shuffle_train_dr1[np.where(shuffle_train_dr1[:,0]>z1[j])]
    dr1_i[j] = shuffle_train_dr1[np.where(shuffle_train_dr1[:,0]<=z1[j])]
    dr1_d[j] = shuffle_train_dr1[np.where(shuffle_train_dr1[:,0]>z1[j])]
    dr2_i[j] = shuffle_train_dr2[np.where(shuffle_train_dr2[:,0]<=z2[j])]
    dr2_d[j] = shuffle_train_dr2[np.where(shuffle_train_dr2[:,0]>z2[j])]
    dr3_i[j] = shuffle_train_dr3[np.where(shuffle_train_dr3[:,0]<=z3[j])]
    dr3_d[j] = shuffle_train_dr3[np.where(shuffle_train_dr3[:,0]>z3[j])]
    dr4_i[j] = shuffle_train_dr4[np.where(shuffle_train_dr4[:,0]<=z4[j])]
    dr4_d[j] = shuffle_train_dr4[np.where(shuffle_train_dr4[:,0]>z4[j])]
    dr5_i[j] = shuffle_train_dr5[np.where(shuffle_train_dr5[:,0]<=z5[j])]
    dr5_d[j] = shuffle_train_dr5[np.where(shuffle_train_dr5[:,0]>z5[j])]
    dr6_i[j] = shuffle_train_dr6[np.where(shuffle_train_dr6[:,0]<=z6[j])]
    dr6_d[j] = shuffle_train_dr6[np.where(shuffle_train_dr6[:,0]>z6[j])]
    dr7_i[j] = shuffle_train_dr7[np.where(shuffle_train_dr7[:,0]<=z7[j])]
    dr7_d[j] = shuffle_train_dr7[np.where(shuffle_train_dr7[:,0]>z7[j])]
    dr8_i[j] = shuffle_train_dr8[np.where(shuffle_train_dr8[:,0]<=z8[j])]
    dr8_d[j] = shuffle_train_dr8[np.where(shuffle_train_dr8[:,0]>z8[j])]
    dr9_i[j] = shuffle_train_dr9[np.where(shuffle_train_dr9[:,0]<=z9[j])]
    dr9_d[j] = shuffle_train_dr9[np.where(shuffle_train_dr9[:,0]>z9[j])]
    dr10_i[j] = shuffle_train_dr10[np.where(shuffle_train_dr10[:,0]<=z10[j])]
    dr10_d[j] = shuffle_train_dr10[np.where(shuffle_train_dr10[:,0]>z10[j])]
    print(dr3_i[j])
    print(dr3_d[j])
# Out:
# []
# [[-0.00876693  0.        ]
#  [ 0.03116322  0.        ]
#  [ 0.11117538  1.        ]
#  ...
#  [ 0.02142792  1.        ]
#  [ 0.02193383  0.        ]
#  [ 0.03797542  1.        ]]
# [[-0.17349198  0.        ]]
# [[-0.00876693  0.        ]
#  [ 0.03116322  0.        ]
#  [ 0.11117538  1.        ]
#  ...
#  [ 0.02142792  1.        ]
#  [ 0.02193383  0.        ]
#  [ 0.03797542  1.        ]]
# [[-0.17349198  0.        ]
#  [-0.16667178  0.        ]]
# [[-0.00876693  0.        ]
#  [ 0.03116322  0.        ]
#  [ 0.11117538  1.        ]
#  ...
#  [ 0.02142792  1.        ]
#  [ 0.02193383  0.        ]
#  [ 0.03797542  1.        ]]
# [[-0.17349198  0.        ]
#  [-0.1632731   0.        ]
#  [-0.16667178  0.        ]]
# [[-0.00876693  0.        ]
#  [ 0.03116322  0.        ]
#  [ 0.11117538  1.        ]
#  ...
#  [ 0.02142792  1.        ]
#  [ 0.02193383  0.        ]
#  [ 0.03797542  1.        ]]
# [[-0.15653893  0.        ]
#  [-0.17349198  0.        ]
#  [-0.1632731   0.        ]
# ...

# %%
#S_i = [[]]*100
Sdr1_i = [[]]*100
Sdr2_i = [[]]*100
Sdr3_i = [[]]*100
Sdr4_i = [[]]*100
Sdr5_i = [[]]*100
Sdr6_i = [[]]*100
Sdr7_i = [[]]*100
Sdr8_i = [[]]*100
Sdr9_i = [[]]*100
Sdr10_i = [[]]*100

for i in range(100):
    #S_i[i] = calcShannonEntropy(p_i[i])
    Sdr1_i[i] = calcShannonEntropy(dr1_i[i])
    Sdr2_i[i] = calcShannonEntropy(dr2_i[i])
    Sdr3_i[i] = calcShannonEntropy(dr3_i[i])
    Sdr4_i[i] = calcShannonEntropy(dr4_i[i])
    Sdr5_i[i] = calcShannonEntropy(dr5_i[i])
    Sdr6_i[i] = calcShannonEntropy(dr6_i[i])
    Sdr7_i[i] = calcShannonEntropy(dr7_i[i])
    Sdr8_i[i] = calcShannonEntropy(dr8_i[i])
    Sdr9_i[i] = calcShannonEntropy(dr9_i[i])
    Sdr10_i[i] = calcShannonEntropy(dr10_i[i])

    #print(Sdr3_i[i])
plt.plot(z1, Sdr1_i, label = 'Sdr1')
plt.plot(z2, Sdr2_i, label = 'Sdr2')
plt.plot(z3, Sdr3_i, label = 'Sdr3')
plt.plot(z4, Sdr4_i, label = 'Sdr4')
plt.plot(z5, Sdr5_i, label = 'Sdr5')
plt.plot(z6, Sdr6_i, label = 'Sdr6')
plt.plot(z7, Sdr7_i, label = 'Sdr7')
plt.plot(z8, Sdr8_i, label = 'Sdr8')
plt.plot(z9, Sdr9_i, label = 'Sdr9')
plt.plot(z10, Sdr10_i, label = 'Sdr10')

plt.legend()
plt.xlabel("$\delta$")
plt.ylabel("Shannon Entropy")
plt.title("Shannon Entropy for partitions to the left of $Z_{i}, i = 1,...,10$, training set")
plt.show()
#, entropy_i[i])

# %%
Sdr1_d = [[]]*100
Sdr2_d = [[]]*100
Sdr3_d = [[]]*100
Sdr4_d = [[]]*100
Sdr5_d = [[]]*100
Sdr6_d = [[]]*100
Sdr7_d = [[]]*100
Sdr8_d = [[]]*100
Sdr9_d = [[]]*100
Sdr10_d = [[]]*100

for i in range(100):
    #S_i[i] = calcShannonEntropy(p_i[i])
    Sdr1_d[i] = calcShannonEntropy(dr1_d[i])
    Sdr2_d[i] = calcShannonEntropy(dr2_d[i])
    Sdr3_d[i] = calcShannonEntropy(dr3_d[i])
    Sdr4_d[i] = calcShannonEntropy(dr4_d[i])
    Sdr5_d[i] = calcShannonEntropy(dr5_d[i])
    Sdr6_d[i] = calcShannonEntropy(dr6_d[i])
    Sdr7_d[i] = calcShannonEntropy(dr7_d[i])
    Sdr8_d[i] = calcShannonEntropy(dr8_d[i])
    Sdr9_d[i] = calcShannonEntropy(dr9_d[i])
    Sdr10_d[i] = calcShannonEntropy(dr10_d[i])
    #print(Sdr3_d[i])
plt.plot(z1, Sdr1_d, label = 'Sdr1')
plt.plot(z2, Sdr2_d, label = 'Sdr2')
plt.plot(z3, Sdr3_d, label = 'Sdr3')
plt.plot(z4, Sdr4_d, label = 'Sdr4')
plt.plot(z5, Sdr5_d, label = 'Sdr5')
plt.plot(z6, Sdr6_d, label = 'Sdr6')
plt.plot(z7, Sdr7_d, label = 'Sdr7')
plt.plot(z8, Sdr8_d, label = 'Sdr8')
plt.plot(z9, Sdr9_d, label = 'Sdr9')
plt.plot(z10, Sdr10_d, label = 'Sdr10')
plt.legend()
plt.xlabel("$\delta$")
plt.ylabel("Shannon Entropy")
plt.title("Shannon Entropy for partitions to the right of $Z_{i}, i = 1, 2, 3, 4$, training set")
plt.show()

# %%
# %matplotlib inline
#%matplotlib qt
#%matplotlib notebook
#DeltaS = [[]]*100
DeltaSdr1 = [[]]*100
DeltaSdr2 = [[]]*100
DeltaSdr3 = [[]]*100
DeltaSdr4 = [[]]*100
DeltaSdr5 = [[]]*100
DeltaSdr6 = [[]]*100
DeltaSdr7 = [[]]*100
DeltaSdr8 = [[]]*100
DeltaSdr9 = [[]]*100
DeltaSdr10 = [[]]*100



for i in range(100):
    
    #DeltaS[i] = - calcShannonEntropy(shuffle_train_dr1) + (len(p_i[i])/float(len(shuffle_train_dr1)) * S_i[i]
     #                                                   +  len(p_d[i])/float(len(shuffle_train_dr1)) * S_d[i])
    DeltaSdr1[i] = - calcShannonEntropy(shuffle_train_dr1) + (len(dr1_i[i])/float(len(shuffle_train_dr1)) * Sdr1_i[i]
                                                        +  len(dr1_d[i])/float(len(shuffle_train_dr1)) * Sdr1_d[i])
    
    DeltaSdr2[i] = - calcShannonEntropy(shuffle_train_dr2) + (len(dr2_i[i])/float(len(shuffle_train_dr2)) * Sdr2_i[i]
                                                        +  len(dr2_d[i])/float(len(shuffle_train_dr2)) * Sdr2_d[i])
    
    DeltaSdr3[i] = - calcShannonEntropy(shuffle_train_dr3) + (len(dr3_i[i])/float(len(shuffle_train_dr3)) * Sdr3_i[i]
                                                        +  len(dr3_d[i])/float(len(shuffle_train_dr3)) * Sdr3_d[i])
    
    DeltaSdr4[i] = - calcShannonEntropy(shuffle_train_dr4) + (len(dr4_i[i])/float(len(shuffle_train_dr4)) * Sdr4_i[i]
                                                        +  len(dr4_d[i])/float(len(shuffle_train_dr4)) * Sdr4_d[i])
    
    DeltaSdr5[i] = - calcShannonEntropy(shuffle_train_dr5) + (len(dr5_i[i])/float(len(shuffle_train_dr5)) * Sdr5_i[i]
                                                        +  len(dr5_d[i])/float(len(shuffle_train_dr5)) * Sdr5_d[i])
    
    DeltaSdr6[i] = - calcShannonEntropy(shuffle_train_dr6) + (len(dr6_i[i])/float(len(shuffle_train_dr6)) * Sdr6_i[i]
                                                        +  len(dr6_d[i])/float(len(shuffle_train_dr6)) * Sdr6_d[i])
    
    DeltaSdr7[i] = - calcShannonEntropy(shuffle_train_dr7) + (len(dr7_i[i])/float(len(shuffle_train_dr7)) * Sdr7_i[i]
                                                        +  len(dr7_d[i])/float(len(shuffle_train_dr7)) * Sdr7_d[i])
    
    DeltaSdr8[i] = - calcShannonEntropy(shuffle_train_dr8) + (len(dr8_i[i])/float(len(shuffle_train_dr8)) * Sdr8_i[i]
                                                        +  len(dr8_d[i])/float(len(shuffle_train_dr8)) * Sdr8_d[i])
    
    DeltaSdr9[i] = - calcShannonEntropy(shuffle_train_dr9) + (len(dr9_i[i])/float(len(shuffle_train_dr9)) * Sdr9_i[i]
                                                        +  len(dr9_d[i])/float(len(shuffle_train_dr9)) * Sdr9_d[i])
    
    DeltaSdr10[i] = - calcShannonEntropy(shuffle_train_dr10) + (len(dr10_i[i])/float(len(shuffle_train_dr10)) * Sdr10_i[i]
                                                        +  len(dr10_d[i])/float(len(shuffle_train_dr10)) * Sdr10_d[i])
    
    
    
    #print(DeltaS[i])
    #prob = len(Sdr1_i)/float(len(Sdr1_i))
     #       newEntropy += prob * calcShannonEnt(subDataSet) 
plt.plot(z1, DeltaSdr1, label = '$\Delta$Sdr1')
plt.plot(z2, DeltaSdr2, label = '$\Delta$Sdr2')
plt.plot(z3, DeltaSdr3, label = '$\Delta$Sdr3')
plt.plot(z4, DeltaSdr4, label = '$\Delta$Sdr4')
plt.plot(z5, DeltaSdr5, label = '$\Delta$Sdr5')
plt.plot(z6, DeltaSdr6, label = '$\Delta$Sdr6')
plt.plot(z7, DeltaSdr7, label = '$\Delta$Sdr7')
plt.plot(z8, DeltaSdr8, label = '$\Delta$Sdr8')
plt.plot(z9, DeltaSdr9, label = '$\Delta$Sdr9')
plt.plot(z10, DeltaSdr10, label = '$\Delta$Sdr10')
print(min(DeltaSdr1))
print(min(DeltaSdr2))
print(min(DeltaSdr3))
print(min(DeltaSdr4))
print(min(DeltaSdr5))
print(min(DeltaSdr6))
print(min(DeltaSdr7))
print(min(DeltaSdr8))
print(min(DeltaSdr9))
print(min(DeltaSdr10))
plt.legend()
plt.xlabel("$\delta$")
plt.ylabel("Difference in Shannon Entropy")
plt.title("Shannon Entropy after each split, training set")
#plt.axvline(0.012)
plt.show()
# Out:
# -0.133775863575
# -0.17605807408
# -0.202586205964
# -0.214772006142
# -0.214379950028
# -0.188002697699
# -0.144800859689
# -0.117943479605
# -0.0796610428
# -0.0557326096804

# %%
z5[48]
# Out:
# 0.009080066825424254

# %% [markdown]
# ### Hacemos una partición para el test set en el valor $z_{5} = 0.009$ que es donde hay un cambio máximo en entropía

# %%
print(calcShannonEntropy(shuffle_test_dr5[np.where(shuffle_test_dr5[:,0]<=0.008)]))
print(calcShannonEntropy(shuffle_test_dr5[np.where(shuffle_test_dr5[:,0]>0.008)]))
# Out:
# 0.781048183587
# 0.791003704496

# %%
Test_i = shuffle_test_dr5[np.where(shuffle_test_dr5[:,0]<=0.008)]
Test_d = shuffle_test_dr5[np.where(shuffle_test_dr5[:,0]>0.008)]

# %%
df1_0 = shuffle_train_dr1[labels == 0]
df1_1 = shuffle_train_dr1[labels == 1]

sns.distplot(shuffle_train_dr1['dr1'], kde=True, hist=False, label='label = 0')
sns.distplot(shuffle_train_dr1['dr1'], kde=True, hist=False, label='label = 1')
plt.axvline(0.012)
plt.legend()
sns.set(style="darkgrid")

plt.show()

# %%
ptest_i = shuffle_test_dr1[np.where(shuffle_test_dr1[:,0]<=z1[43])]
ptest_d = shuffle_test_dr1[np.where(shuffle_test_dr1[:,0]>z1[43])]

# %%
print(calcShannonEntropy(ptest_i))
print(calcShannonEntropy(ptest_d))

# %% [markdown]
# ### Calculamos su entropía

# %%
print(calcShannonEntropy(shuffle_test_dr1) - len(ptest_i)/float(len(shuffle_test_dr1))*calcShannonEntropy(ptest_i))
print(calcShannonEntropy(shuffle_test_dr1) - len(ptest_d)/float(len(shuffle_test_dr1))*calcShannonEntropy(ptest_d))

#print(calcShannonEntropy(ptest_dr1_d))
#print(np.shape(ptest_dr1_i))
#print(np.shape(ptest_dr1_d))

# %% [markdown]
# ## Arbol de decision con ScikitLearn

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X_train = np.reshape(shuffle_train_dr1[:,0], (-1,1))
#print(X_train)
X_test = np.reshape(shuffle_test_dr1[:,0], (-1,1))
y_train = shuffle_train_dr1[:,1]
y_test = shuffle_test_dr1[:,1]

# %%
y_test
# Out:
# array([0., 0., 1., ..., 1., 0., 1.])

# %% [markdown]
# ### Construir Arbol de decision

# %%
#Create Decision tree classifier object
dt = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=10)
#train decision tree classifier
dt = dt.fit(X_train, y_train)
#Predict the response for test dataset
y_pred = dt.predict(X_test)
#Model accuracy, how often is the classifier correct
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy:', 0.7253)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax


np.set_printoptions(precision=2)

# %%
class_names=['Not in Halo','in Halo']
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(y_test, y_pred, classes=class_names,normalize = True,
                      title='Confusion matrix')
# Out:
# Normalized confusion matrix
# [[0.75 0.25]
#  [0.29 0.71]]

# %%
np.shape(y_pred)

# %%
np.sum(y_pred)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# ## ROC curve

# %%
r_probs = [0 for _ in range(len(y_test))]
dt_probs = dt.predict_proba(X_test)

# %%
dt_probs = dt_probs[:, 1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

# %%
r_auc = roc_auc_score(y_test, r_probs)
dt_auc = roc_auc_score(y_test, dt_probs)

# %%
print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Decision Tree: AUROC = %.3f' % (dt_auc))

# %%
r_fpr, r_tpr, _ = roc_curve(y_test, r_probs)
dt_fpr, dt_tpr, _ = roc_curve(y_test, dt_probs)

# %%
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(dt_fpr, dt_tpr, marker='.', label='Decision Tree (AUROC = %0.3f)' % dt_auc)
plt.title('ROC Plot')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()

# %% [markdown]
# ## Precision-Recall curve

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# %%
df.sort_values('labels').head(32456)
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 0     -0.072444 -0.061586 -0.051498 -0.043164 -0.042943 -0.038666 -0.022006
# 29843 -0.067475 -0.043668 -0.035297 -0.025401 -0.022461 -0.024166 -0.017822
# 29844 -0.098441 -0.065531 -0.057053 -0.051051 -0.029729 -0.011730 -0.002959
# 29846  0.016320  0.002836  0.001457  0.015831  0.022169  0.016522  0.006750
# 29847 -0.036306 -0.034049 -0.035939 -0.032215 -0.027422 -0.021427 -0.018117
# 29848 -0.018956 -0.043564 -0.035319 -0.021257 -0.023497 -0.027577 -0.017708
# 29849 -0.060394 -0.047505 -0.046802 -0.047362 -0.046510 -0.040300 -0.033574
# 29850 -0.009036 -0.014998 -0.016193 -0.013029 -0.009270 -0.019846 -0.029371
# 29851 -0.022849 -0.020845 -0.011379  0.003112  0.009683  0.012551  0.019813
# 29852  0.013655  0.031135  0.036388  0.027735  0.018133  0.002368  0.004972
# 29854 -0.026517 -0.016906 -0.005138  0.006541  0.016124  0.015886  0.017338
# ...

# %%
df_0 = df.sort_values('labels').head(32456).sample(17000)
df_1 = df.sort_values('labels').tail(17544).sample(17000) 
df_0
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 36862  0.051697  0.022451  0.011245  0.009613  0.007870  0.009943  0.013264
# 8319  -0.052766 -0.042791 -0.038443 -0.030939 -0.029889 -0.025582 -0.013800
# 49073 -0.006332 -0.009651 -0.014187 -0.017879 -0.017160 -0.020693 -0.021291
# 25105  0.051319  0.038469  0.019736  0.007598 -0.001145 -0.011466 -0.017712
# 23473  0.110736  0.061409  0.044751  0.032408  0.019078  0.008596  0.014447
# 11604 -0.130772 -0.103984 -0.076774 -0.051059 -0.033341 -0.013332 -0.006010
# 48822 -0.036630 -0.038715 -0.033096 -0.041532 -0.044884 -0.039346 -0.029494
# 1780   0.007663 -0.003659 -0.009085 -0.011300 -0.005769 -0.006311 -0.004074
# 7299  -0.007535 -0.002059 -0.001915 -0.010934 -0.012948 -0.008994 -0.004893
# 30693 -0.149077 -0.140930 -0.122706 -0.101522 -0.085816 -0.077569 -0.066910
# 33742 -0.087131 -0.082385 -0.084858 -0.086334 -0.088912 -0.081345 -0.072030
# ...

# %%
from sklearn.utils import shuffle
df_r = pd.concat([df_0, df_1])
df_r = shuffle(df_r)
df_r
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 27989  0.108938  0.094285  0.086724  0.073423  0.056791  0.043346  0.027331
# 28404 -0.041728 -0.042882 -0.036039 -0.019203 -0.009350 -0.011960 -0.001247
# 20286  0.049666  0.044837  0.060899  0.069909  0.060315  0.049907  0.036540
# 10408  0.096436  0.112516  0.113960  0.107272  0.100699  0.084075  0.061936
# 26659  0.215862  0.158990  0.129269  0.107109  0.084989  0.056873  0.032337
# 17506  0.029326  0.040621  0.032945  0.020806  0.018708  0.014330  0.009022
# 36425  0.025267  0.015800  0.024655  0.025625  0.022910  0.022197  0.031950
# 310    0.133441  0.130354  0.127177  0.123189  0.110869  0.089494  0.067425
# 8953   0.115850  0.111421  0.100249  0.070574  0.048891  0.043324  0.039537
# 42058  0.087151  0.083172  0.075231  0.061574  0.061278  0.049826  0.040522
# 47554  0.042229  0.037714  0.028473  0.017896  0.017296  0.018802  0.018924
# ...

# %%
features = ['dr1', 'dr2', 'dr3', 'dr4', 'dr5', 'dr6', 'dr7', 'dr8', 'dr9', 'dr10']
X = df_r[features]
y = df_r.labels

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1)

# %%
#Create Decision tree classifier object, we can change the min_samples_leaf for better accuracy
dt = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=200)
#train decision tree classifier
dt = dt.fit(X_train, y_train)
#Predict the response for test dataset
y_pred = dt.predict(X_test)
#Model accuracy, how often is the classifier correct
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy:', 0.7822058823529412)

# %%
class_names=['Not in Halo','in Halo']
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(y_test, y_pred, classes=class_names, normalize=True,
                      title='Confusion matrix for in/out classes')
# Out:
# Normalized confusion matrix
# [[0.76 0.24]
#  [0.19 0.81]]

# %%
r_probs = [0 for _ in range(len(y_test))]
dt_probs = dt.predict_proba(X_test)

# %%
dt_probs = dt_probs[:, 1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
r_auc = roc_auc_score(y_test, r_probs)
dt_auc = roc_auc_score(y_test, dt_probs)

# %%
print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Decision Tree: AUROC = %.3f' % (dt_auc))
#print('Naive Bayes: AUROC = %.3f' % (nb_auc))
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Decision Tree: AUROC = 0.857

# %%
r_fpr, r_tpr, _ = roc_curve(y_test, r_probs)
dt_fpr, dt_tpr, _ = roc_curve(y_test, dt_probs)

# %%
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(dt_fpr, dt_tpr, marker='.', label='Decision Tree (AUROC = %0.3f)' % dt_auc)
#plt.plot(nb_fpr, nb_tpr, marker='.', label='Naive Bayes (AUROC = %0.3f)' % nb_auc)

# Title
plt.title('ROC Plot')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()

# %%
from sklearn import tree
from graphviz import Source

X = df_r.drop('labels', axis=1).values
y = df_r['labels'].values

model = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth=4, min_samples_leaf=200)
model.fit(X, y)

graph = Source(tree.export_graphviz(model, out_file=None,
                                    feature_names=df_r.columns[1:],
                                    class_names=['Not in Halo', 'in Halo'],
                                    filled=True, rounded=True))
graph
