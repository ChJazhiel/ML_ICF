# %% [markdown]
# # Import utilites

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# CHECK IF STANDARDIZED VALUES HAVE AN IMPACT ON THE RESULT
#
#
# -Normalization is good to use when you know that the distribution of your data does not follow a Gaussian distribution. This can be useful in algorithms that do not assume any distribution of the data like K-Nearest Neighbors and Neural Networks.
#
# -Standardization, on the other hand, can be helpful in cases where the data follows a Gaussian distribution. However, this does not have to be necessarily true. Also, unlike normalization, standardization does not have a bounding range. So, even if you have outliers in your data, they will not be affected by standardization.
#
#
# SO far, I have not seen any difference when doing standardization on the data

# %% [markdown]
# # Load dataset

# %%
dict_data = np.load('nbody_data.npz')
test_flags  = dict_data['test_flags']
test_hosts  = dict_data['test_hosts']
test_mass   = dict_data['test_mass']
test_labels = dict_data['test_labels']
test_input  = dict_data['test_input']
#test_snid   = dict_data['test_snid']
#test_labels = dict_data['test_labels']
print(test_mass)
print(np.sum(test_labels))
# Out:
# [-1.00000000e+00 -1.00000000e+00 -1.00000000e+00 ...  3.43922706e+12
#   3.73214214e+12 -1.00000000e+00]
# 17544

# %% [markdown]
# # Visualize dataset distribution

# %%
dr1 = pd.DataFrame(test_input[0], columns = ['dr1'])
dr2 = pd.DataFrame(test_input[1], columns = ['dr2'])
dr3 = pd.DataFrame(test_input[2], columns = ['dr3'])
dr4 = pd.DataFrame(test_input[3], columns = ['dr4'])
dr5 = pd.DataFrame(test_input[4], columns = ['dr5'])
dr6 = pd.DataFrame(test_input[5], columns = ['dr6'])
dr7 = pd.DataFrame(test_input[6], columns = ['dr7'])
dr8 = pd.DataFrame(test_input[7], columns = ['dr8'])
dr9 = pd.DataFrame(test_input[8], columns = ['dr9'])
dr10 = pd.DataFrame(test_input[9], columns = ['dr10'])
lbl = pd.DataFrame(test_labels, columns =['labels'])

df = pd.concat([dr1, dr2, dr3, dr4, dr5, dr6, dr7, dr8, dr9, dr10, lbl], axis=1, ignore_index=False, sort=False)
df.describe()
# Out:
#                 dr1           dr2           dr3           dr4           dr5  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.005127      0.003976      0.003287      0.002492      0.001943
# std        0.064751      0.056255      0.050816      0.043809      0.038280
# min       -0.227063     -0.194014     -0.173785     -0.159018     -0.138782
# 25%       -0.039752     -0.034953     -0.031945     -0.028010     -0.024414
# 50%        0.002010      0.001781      0.001620      0.001314      0.001093
# 75%        0.047154      0.040558      0.036602      0.031390      0.027280
# max        0.325070      0.281706      0.253833      0.205020      0.166184
#
#                 dr6           dr7           dr8           dr9          dr10  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.001504      0.001148      0.000830      0.000575      0.000387
# ...

# %%
import seaborn as sns
#import seaborn as sns
# %matplotlib inline
#%matplotlib qt
#matplotlib notebook

df1_0 = df[df.labels == 0]
df1_1 = df[df.labels == 1]

sns.distplot(df1_0['dr1'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr1'], kde=True, hist=False, label='label = 1')
plt.axvline(0.012)
plt.legend()
sns.set(style="darkgrid")
plt.show()


sns.distplot(df1_0['dr2'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr2'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr3'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr3'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr4'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr4'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr5'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr5'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr6'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr6'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr7'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr7'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr8'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr8'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr9'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr9'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

sns.distplot(df1_0['dr10'], kde=True, hist=False, label='label = 0')
sns.distplot(df1_1['dr10'], kde=True, hist=False, label='label = 1')
#plt.axvline()
plt.legend()
sns.set(style="darkgrid")
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df.iloc[:, :-1].corr()
sns.heatmap(corr,
            xticklabels=corr.columns,
            yticklabels=corr.columns)
plt.show()

# %% [markdown]
# #  sort values by labels, concatenate and shuffle to train test split data
# I did tested this with train_test_split() function from sklearn and see no further evidence of an improvement

# %% [markdown]
# Concatenate the dataset by its labels and merge, then random shuffle the samples taking into account we have a balanced class list (17000 label 0 and 17000 label 1)

# %%
df_0 = df.sort_values('labels').head(32456).sample(17300)
df_1 = df.sort_values('labels').tail(17544).sample(17300) 
df_1



df_r = pd.concat([df_0, df_1]) ###MERGE THE DATASET
shuffle_df = df_r.sample(frac = 1.0)  ### SHUFFLE THE DATASET EVENLY

train_size = int(0.8 * len(df_r)) # Define a size for your train set 


train_set = shuffle_df[:train_size] # Split your dataset 
test_set = shuffle_df[train_size:] 

#THE "Disadvantage" with this process is that our sets are not randomly selected
# in change we select the first rows as the training set, and the last rows as the test set
#but, as I stated previously, this DOES NOT affect the overall result
shuffle_df
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 41420  0.047614  0.021523  0.007986 -0.003520 -0.010725 -0.017573 -0.020090
# 1013  -0.023785 -0.034004 -0.044809 -0.045157 -0.034896 -0.025966 -0.010266
# 23067  0.057677  0.044958  0.031994  0.013111  0.002927  0.003823 -0.005544
# 46856 -0.080732 -0.068080 -0.057167 -0.049563 -0.039774 -0.031647 -0.022468
# 36691  0.010666  0.007803  0.019186  0.019547  0.006968  0.001775  0.007646
# 14280  0.089220  0.067483  0.055689  0.052948  0.043919  0.028725  0.009641
# 15660  0.068130  0.066178  0.063229  0.054610  0.042183  0.031063  0.014886
# 16872 -0.054471 -0.028370 -0.011595  0.006655  0.014767  0.012735  0.005863
# 39199  0.111702  0.087679  0.071527  0.050733  0.044485  0.036602  0.039543
# 26441  0.053794  0.052344  0.058722  0.061454  0.055331  0.051109  0.036949
# 29460 -0.018640 -0.028131 -0.033826 -0.025280 -0.014944 -0.008992  0.000615
# ...

# %%
#### THIS CELL IS FOR CALCULATE THE CONFUSION MATRIX ####


#### IMPORTANT NOTE: In a future patch we should be able to create
#### the plot_confusion_matrix.py script to just import from the 
#### cells, I'm not quite sure how that would work

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax
    


np.set_printoptions(precision=2)

# %% [markdown]
# # select the data values, X for the attributes, y for the labels

# %%
X = shuffle_df.drop(['labels'], axis = 1)
y = shuffle_df.labels
X_train = train_set.drop(['labels'], axis = 1)
X_test = test_set.drop(['labels'], axis= 1)
y_train = train_set.labels
y_test = test_set.labels

# %% [markdown]
# # Import sklearn models and metrics, for this we use Decision tree classifier and cross validation score to test accuracy metric

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RepeatedStratifiedKFold

# %% [markdown]
# # Create the Decision tree classifier for the above dataset, notice the kwargs on the DecisionTreeClassifer() function, as the max_depth and min_samples_leaf will be explained further

# %%
### Criterion=entropy: Shannon entropy for binary classification, Entropy is best because the 
### average entropy after a split is usually not the same for the parent node as it is for a child node
### the division rule continues until we get a pure node

### min samples leaf = 20: I choose this number because Rockstar uses a similar threshold to determine
### wheter the code would give you a halo or not, by default, a halo is defined by 20 particles minimum

### class weight = balanced: we know, for simple construction that our dataset is evenly distributed 
### by labels, so it is a good choice, at least from my point of view, to say that the class weights are 
### balanced

### max depth = 8: going very deep in our decision tree would lead in overfitting, this has to do with 
### the problem of misclassification and learning from noise rather than data
### I would choose 10, as 10 is the number of features we have at our disposal, and thinking that 
### each split gets rid ofo of 1 feature, this would be acceptable but I've seen from various testings
### that this leads to overfitting

dt = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt = dt.fit(X_train, y_train)

#Predict the response for test dataset
ypred = dt.predict(X_test)
#Model accuracy, how often is the classifier correct

print('Traning and Testing on raw data, all features \n');

print("Accuracy:", metrics.accuracy_score(y_test, ypred))

for i, score_tree in enumerate(cross_val_score(dt, X, y, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt, X, y, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

### We perform a cross validation score to see how accurate our decision tree is by 
### splitting the dataset into 10 folds for training and testing
# Out:
# Traning and Testing on raw data, all features
#
# ('Accuracy:', 0.7765895953757226)
# Decision tree accuracy for the 0 score: 0.77
# Decision tree accuracy for the 1 score: 0.77
# Decision tree accuracy for the 2 score: 0.77
# Decision tree accuracy for the 3 score: 0.78
# Decision tree accuracy for the 4 score: 0.77
# Decision tree accuracy for the 5 score: 0.76
# Decision tree accuracy for the 6 score: 0.76
# Decision tree accuracy for the 7 score: 0.76
# Decision tree accuracy for the 8 score: 0.78
# Decision tree accuracy for the 9 score: 0.77
# Decision Tree Accuracy: 0.77 (+/- 0.01)

# %% [markdown]
# # Confusion Matrix

# %%
class_names=['Not in Halo','In Halo']
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(y_test, ypred, classes=class_names, normalize=True,
                      title='Confusion matrix, raw data')
plt.grid(False)
#plt.savefig('/home/jazhiel/Escritorio/Maestria/Machine_Learning/IMG_Tesis/Conf1.png')
plt.show()
# Out:
# Normalized confusion matrix
# [[0.74 0.26]
#  [0.19 0.81]]

# %% [markdown]
# We see that for our model, the confusion matrix is actually pretty good, we can check if we can improve it by changing some kwargs on the decision tree function, it also would be helpful to call the plot tree function from exportgraph viz, but as a 10 depth tree, it is very large, we'll check on that later

# %% [markdown]
# # ROC CURVE
# The ROC curve is a visual representation of our classifier, it graphs the contrast of TPR and FPR of various thresholds, it is directly calculated from the decision tree and the confusion matriz, this is where number of samples in classification nodes becomes important, if we don't set a threshold in that particular case, the ROC curve is a sharp line, meaning that the classification is 100 % correct or incorrect, whereas giving a min number of samples for leaf nodes gives us the following statement "we have a particle that fell (not fell) inside a halo with this probability" ROC curves are, in a sort of speaking, a representation of that probability.
#
# The AUC of the ROC curve, however, is the important feature here, as it tells us how good our classifier is.
#
# The scores goes as the following
#
# .- AUC = 1.0 - 0.9: great classificator, even perfect
#
# .- AUC = 0.89 - 0.8: good classificator
#
# .- AUC = 0.79 - 0.7: not so bad classificator
#
# .- AUC = 0.69 - 0.6: not good classificator
#
# .- AUC = 0.59 and below: almost random or completely random classificator (your model is not learning)

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

r_probs = [0 for _ in range(len(y_test))] ### random classification values
dt_probs = dt.predict_proba(X_test) ### predicts probabilities discussed before
dt_probs = dt_probs[:, 1] ## we choose the first column

r_auc = roc_auc_score(y_test, r_probs)
dt_auc = roc_auc_score(y_test, dt_probs)

print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Decision Tree: AUROC = %.3f' % (dt_auc))

r_fpr, r_tpr, _ = roc_curve(y_test, r_probs)
dt_fpr, dt_tpr, _ = roc_curve(y_test, dt_probs)
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(dt_fpr, dt_tpr, marker='.', label='Decision Tree (AUROC = %0.3f)' % dt_auc)
plt.title('ROC Plot, raw data') #all features, ENZO dataset')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.savefig('/home/jazhiel/Escritorio/Maestria/Machine_Learning/IMG_Tesis/ROC_plot1.png')
plt.show()
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Decision Tree: AUROC = 0.847

# %% [markdown]
# # Learning Curve
# It shows if our model can be improved by using more data or reducing features, it is said that the model is "learning" if the accuracy score of the validation set goes up in the "y" axis, the high accuracy on the training set is due to "underfitting" but eventually comes closer to the value of the validation set

# %%
from sklearn.model_selection import learning_curve
# Create CV training and test scores for various training set sizes
train_sizes, train_scores, test_scores = learning_curve(dt, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# %%
#Create means and standard deviations for train set scores

train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color='r',  label="Training score")
plt.plot(train_sizes, test_mean, color='b', label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes,
                 train_mean - train_std,
                 train_mean + train_std,
                 color="r", alpha =0.15)

plt.fill_between(train_sizes,
                 test_mean - test_std,
                 test_mean + test_std,
                 color="b", alpha = 0.15)

# Create plot
plt.title("Learning Curve") # All Features, ENZO dataset")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.savefig('/home/jazhiel/Escritorio/Maestria/Machine_Learning/IMG_Tesis/Learning_1.png')
plt.show()

# %% [markdown]
# # Feature Importance
#
# How important are the features in our ds in order to make decisions and reduce entropy

# %%
features = ['dr1', 'dr2', 'dr3', 'dr4', 'dr5', 'dr6', 'dr7', 'dr8', 'dr9', 'dr10']

feature_imp = pd.Series(dt.feature_importances_,index=features)
print(feature_imp)

# Creating a bar plot
sns.barplot(x=feature_imp.index, y=feature_imp)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features, raw data")
plt.legend()
plt.show()
# Out:
# dr1     0.008390
# dr2     0.028714
# dr3     0.019014
# dr4     0.729148
# dr5     0.097190
# dr6     0.012611
# dr7     0.046710
# dr8     0.012957
# dr9     0.027912
# dr10    0.017354
# dtype: float64

# %% [markdown]
# # Now, what if we rescale the dataset, of course, after selecting the labels

# %%
shuffle_df.describe()
# Out:
#                 dr1           dr2           dr3           dr4           dr5  \
# count  34600.000000  34600.000000  34600.000000  34600.000000  34600.000000
# mean       0.014507      0.012831      0.011646      0.009928      0.008378
# std        0.065847      0.057130      0.051510      0.044217      0.038526
# min       -0.227063     -0.192813     -0.166547     -0.145203     -0.129241
# 25%       -0.031162     -0.026773     -0.024070     -0.020329     -0.018008
# 50%        0.012301      0.011915      0.011397      0.009921      0.008546
# 75%        0.058254      0.050903      0.046468      0.039700      0.034198
# max        0.325070      0.281706      0.253833      0.205020      0.166184
#
#                 dr6           dr7           dr8           dr9          dr10  \
# count  34600.000000  34600.000000  34600.000000  34600.000000  34600.000000
# mean       0.006769      0.005253      0.003926      0.002795      0.001915
# ...

# %%
# PERFORM Data standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

features_scaled = scaler.fit_transform(df_r.drop(['labels'], axis = 1))  
features_scaled = pd.DataFrame(features_scaled , columns=['dr1', 'dr2', 'dr3', 'dr4', 'dr5', 'dr6', 'dr7', 'dr8', 'dr9', 'dr10'])
features_scaled.describe()

#shuffle_df = df_r.sample(frac = 1.0)
#shuffle_df.insert(10, "Model", ['LC','SF']*14300, True)
#shuffle_df
#df_scaled = pd.DataFrame(df_scaled)
# Out:
#                 dr1           dr2           dr3           dr4           dr5  \
# count  3.460000e+04  3.460000e+04  3.460000e+04  3.460000e+04  3.460000e+04
# mean   1.396006e-15 -4.151143e-16 -2.131506e-15 -1.059897e-15  4.766066e-16
# std    1.000014e+00  1.000014e+00  1.000014e+00  1.000014e+00  1.000014e+00
# min   -3.668683e+00 -3.599630e+00 -3.459420e+00 -3.508422e+00 -3.572219e+00
# 25%   -6.935712e-01 -6.932368e-01 -6.933971e-01 -6.842918e-01 -6.849019e-01
# 50%   -3.350380e-02 -1.602151e-02 -4.843869e-03 -1.566355e-04  4.352129e-03
# 75%    6.643756e-01  6.664172e-01  6.760240e-01  6.733099e-01  6.701997e-01
# max    4.716471e+00  4.706454e+00  4.701790e+00  4.412179e+00  4.096190e+00
#
#                 dr6           dr7           dr8           dr9          dr10
# count  3.460000e+04  3.460000e+04  3.460000e+04  3.460000e+04  3.460000e+04
# mean  -1.493603e-15 -1.264756e-15 -5.548163e-16 -1.036133e-15  5.754742e-16
# ...

# %% [markdown]
# We see now that our data of the selected particles is rescaled (standardized), now we have to concatenate or attach the labels to each row

# %%
features_scaled['labels'] = df_r['labels'].values
features_scaled
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 0     -1.685662 -1.330558 -1.067731 -1.074122 -1.346826 -1.317957 -1.044498
# 1      1.149776  1.429422  1.453403  1.275121  1.183326  1.200688  0.973452
# 2     -0.929373 -1.188058 -1.501017 -1.677508 -1.612178 -1.710960 -1.187365
# 3     -1.243101 -1.842172 -2.365618 -2.591087 -2.704597 -2.691432 -2.104243
# 4      0.133771  0.208996  0.109736  0.085167  0.014079 -0.132853 -0.353195
# 5     -1.296723 -1.291808 -1.331796 -1.421701 -1.279178 -1.272766 -1.211465
# 6     -1.918512 -2.051307 -1.974071 -1.649446 -1.143037 -0.959351 -0.944040
# 7     -0.806983 -0.772735 -0.666598 -0.503086 -0.589388 -0.586750 -0.386026
# 8      0.154928  0.035637 -0.158173 -0.599222 -0.968905 -1.162042 -1.191781
# 9     -0.723225 -0.751421 -0.846358 -1.173662 -1.369181 -1.570669 -1.382222
# 10     0.676137  1.073090  1.264174  0.955764  0.581016  0.417083  0.306110
# ...

# %% [markdown]
# We perform now a new shuffling of the dataset

# %%
shuffled_scaled = features_scaled.sample(frac=1.0)
shuffled_scaled
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 1557  -0.123203 -0.066413 -0.199466 -0.168204  0.006566  0.155033  0.254087
# 110    0.708131  0.237052 -0.016352 -0.177749 -0.423827 -0.713522 -0.953441
# 5506  -0.759031 -0.545744 -0.267477  0.236478  0.564022  0.537665  0.139196
# 18760 -1.264443 -1.155656 -1.053748 -0.735158 -0.493949 -0.477662 -0.202489
# 821    0.166060  0.399370  0.712420  0.961234  0.757985  0.372964  0.135510
# 20742 -0.160685  0.279263  0.142839  0.011643  0.150888  0.534042  0.875321
# 6283  -1.574223 -1.197869 -0.828884 -0.166727  0.192238  0.160176  0.040419
# 32660  0.682728  0.610483  0.628588  0.680631  0.790417  0.654572  0.439547
# 31288 -0.847410 -0.362672  0.058090  0.457997  0.918668  1.303927  1.188439
# 24036  1.009161  0.955723  0.734423  0.305062  0.045034 -0.368519 -0.417210
# 29265  0.268030  0.519627  0.509021  0.345624  0.221455  0.136784  0.769816
# ...

# %% [markdown]
# We define a new training and testing set for the rescaled features

# %%
# Define a size for your train set 
train_size1 = int(0.8 * len(df_r))

# Split your dataset 
train_set1 = shuffled_scaled[:train_size1]
test_set1 = shuffled_scaled[train_size1:]
train_set1
# Out:
#             dr1       dr2       dr3       dr4       dr5       dr6       dr7  \
# 1557  -0.123203 -0.066413 -0.199466 -0.168204  0.006566  0.155033  0.254087
# 110    0.708131  0.237052 -0.016352 -0.177749 -0.423827 -0.713522 -0.953441
# 5506  -0.759031 -0.545744 -0.267477  0.236478  0.564022  0.537665  0.139196
# 18760 -1.264443 -1.155656 -1.053748 -0.735158 -0.493949 -0.477662 -0.202489
# 821    0.166060  0.399370  0.712420  0.961234  0.757985  0.372964  0.135510
# 20742 -0.160685  0.279263  0.142839  0.011643  0.150888  0.534042  0.875321
# 6283  -1.574223 -1.197869 -0.828884 -0.166727  0.192238  0.160176  0.040419
# 32660  0.682728  0.610483  0.628588  0.680631  0.790417  0.654572  0.439547
# 31288 -0.847410 -0.362672  0.058090  0.457997  0.918668  1.303927  1.188439
# 24036  1.009161  0.955723  0.734423  0.305062  0.045034 -0.368519 -0.417210
# 29265  0.268030  0.519627  0.509021  0.345624  0.221455  0.136784  0.769816
# ...

# %% [markdown]
# We select the features and labels to perform the decision tree and cross validation accuracy scores

# %%
Xscaled = shuffled_scaled.drop(['labels'], axis = 1)
yscaled_labels = shuffled_scaled.labels
#yscaled_model = shuffled_dfr.Model
#ymodel = copy1.Model
X_train_scaled = train_set1.drop(['labels'], axis = 1)
X_test_scaled = test_set1.drop(['labels'], axis= 1)
y_trainl_scaled = train_set1.labels
y_testl_scaled = test_set1.labels

# %% [markdown]
# # Decision tree with scaled features

# %%
### Criterion=entropy: Shannon entropy for binary classification, Entropy is best because the 
### average entropy after a split is usually not the same for the parent node as it is for a child node
### the division rule continues until we get a pure node

### min samples leaf = 20: I choose this number because Rockstar uses a similar threshold to determine
### wheter the code would give you a halo or not, by default, a halo is defined by 20 particles minimum

### class weight = balanced: we know, for simple construction that our dataset is evenly distributed 
### by labels, so it is a good choice, at least from my point of view, to say that the class weights are 
### balanced

### max depth = 8: going very deep in our decision tree would lead in overfitting, this has to do with 
### the problem of misclassification and learning from noise rather than data
### I would choose 10, as 10 is the number of features we have at our disposal, and thinking that 
### each split gets rid ofo of 1 feature, this would be acceptable but I've seen from various testings
### that this leads to overfitting

dt1 = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt1 = dt1.fit(X_train_scaled, y_trainl_scaled)
#Predict the response for test dataset
ypredl_scaled = dt1.predict(X_test_scaled)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on all features scaled\n')
print("Accuracy:", metrics.accuracy_score(y_testl_scaled, ypredl_scaled))
for i, score_tree in enumerate(cross_val_score(dt1, Xscaled, yscaled_labels, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt1, Xscaled ,yscaled_labels, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)
# Out:
# Training and testing on all features scaled
#
# ('Accuracy:', 0.7687861271676301)
# Decision tree accuracy for the 0 score: 0.78
# Decision tree accuracy for the 1 score: 0.77
# Decision tree accuracy for the 2 score: 0.77
# Decision tree accuracy for the 3 score: 0.77
# Decision tree accuracy for the 4 score: 0.77
# Decision tree accuracy for the 5 score: 0.77
# Decision tree accuracy for the 6 score: 0.77
# Decision tree accuracy for the 7 score: 0.77
# Decision tree accuracy for the 8 score: 0.77
# Decision tree accuracy for the 9 score: 0.78
# Decision Tree Accuracy: 0.77 (+/- 0.01)

# %% [markdown]
# # CONFUSION matrix scaled features

# %%
class_names=['Not in Halo','in Halo']
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(y_testl_scaled, ypredl_scaled, classes=class_names, normalize=True,
                      title='Confusion matrix, GADGET scaled features')
plt.grid(False)
plt.show()
# Out:
# Normalized confusion matrix
# [[0.72 0.28]
#  [0.19 0.81]]

# %% [markdown]
# compare the matrices

# %%
plt.figure()
plot_confusion_matrix(y_testl_scaled, ypredl_scaled, classes=class_names, normalize=True,
                      title='Confusion matrix, ENZO scaled features')
plt.grid(False)
plt.show()


plt.figure()
plot_confusion_matrix(y_test, ypred, classes=class_names, normalize=True,
                      title='Confusion matrix, ENZO raw features')
plt.grid(False)
plt.show()
# Out:
# Normalized confusion matrix
# [[0.72 0.28]
#  [0.19 0.81]]
# Normalized confusion matrix
# [[0.74 0.26]
#  [0.19 0.81]]

# %% [markdown]
# # ROC PLOT, scaled features

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

r_probs = [0 for _ in range(len(y_testl_scaled))]
dt1_probs = dt1.predict_proba(X_test_scaled)
dt1_probs = dt1_probs[:, 1]

r_auc = roc_auc_score(y_testl_scaled, r_probs)
dt1_auc = roc_auc_score(y_testl_scaled, dt1_probs)

print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Decision Tree: AUROC = %.3f' % (dt1_auc))

r_fpr, r_tpr, _ = roc_curve(y_testl_scaled, r_probs)
dt1_fpr, dt1_tpr, _ = roc_curve(y_testl_scaled, dt1_probs)
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(dt1_fpr, dt1_tpr, marker='.', label='Decision Tree standardized(AUROC = %0.3f)' % dt1_auc)
#plt.plot(dt_fpr, dt_tpr, marker = '.', label='Decision tree (AUROC = %0.3f)' % dt_auc)
plt.title('ROC Plot, ENZO DS, scaled features')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Decision Tree: AUROC = 0.839

# %% [markdown]
# # Compare the two ROC plots

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

r_probs = [0 for _ in range(len(y_testl_scaled))]
dt1_probs = dt1.predict_proba(X_test_scaled)
dt1_probs = dt1_probs[:, 1]

r_auc = roc_auc_score(y_testl_scaled, r_probs)
dt1_auc = roc_auc_score(y_testl_scaled, dt1_probs)

print('Random (chance) Prediction: AUROC = %.3f' % (r_auc))
print('Standardized data: AUROC = %.3f' % (dt1_auc))
print('Raw data: AUROC = %.3f' % (dt_auc))


r_fpr, r_tpr, _ = roc_curve(y_testl_scaled, r_probs)
dt1_fpr, dt1_tpr, _ = roc_curve(y_testl_scaled, dt1_probs)
plt.plot(r_fpr, r_tpr, linestyle='--', label='Random prediction (AUROC = %0.3f)' % r_auc)
plt.plot(dt1_fpr, dt1_tpr, marker='.', label='Standardized data (AUROC = %0.3f)' % dt1_auc)
plt.plot(dt_fpr, dt_tpr, marker = '.', label='Raw data (AUROC = %0.3f)' % dt_auc)
plt.title('ROC Plot, Decision Tree Classifier')
# Axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Show legend
plt.legend() # 
# Show plot
plt.show()
# Out:
# Random (chance) Prediction: AUROC = 0.500
# Standardized data: AUROC = 0.839
# Raw data: AUROC = 0.847

# %% [markdown]
# # Important Features, scaled

# %%
features = ['dr1', 'dr2', 'dr3', 'dr4', 'dr5', 'dr6', 'dr7', 'dr8', 'dr9', 'dr10']
feature_imp = pd.Series(dt1.feature_importances_,index=features)
print(feature_imp)

# Creating a bar plot
sns.barplot(x=feature_imp.index, y=feature_imp)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features, scaled")
plt.legend()
plt.show()
# Out:
# dr1     0.010449
# dr2     0.024628
# dr3     0.022121
# dr4     0.731160
# dr5     0.100578
# dr6     0.018094
# dr7     0.032878
# dr8     0.030537
# dr9     0.012851
# dr10    0.016705
# dtype: float64

# %% [markdown]
# it conserves importance, so nothing to worry about

# %% [markdown]
# # Now we want to select important features and compare them, we can do  that by selecting features recursively and see the overall importancethen recursive elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.pipeline import Pipeline

# %% [markdown]
# RFE is a transform. To use it, first the class is configured with the chosen algorithm specified via the “estimator” argument and the number of features to select via the “n_features_to_select” argument.
#
# The algorithm must provide a way to calculate important scores, such as a decision tree. The algorithm used in RFE does not have to be the algorithm that is fit on the selected features; different algorithms can be used.

# %% [markdown]
# Once configured, the class must be fit on a training dataset to select the features by calling the fit() function. After the class is fit, the choice of input variables can be seen via the “support_” attribute that provides a True or False for each input variable.
#
# It can then be applied to the training and test datasets by calling the transform() function.
#
#
# Next, we can evaluate an RFE feature selection algorithm on this dataset. We will use a DecisionTreeClassifier to choose features and set the number of features to five. We will then fit a new DecisionTreeClassifier model on the selected features.
#
# We will evaluate the model using repeated stratified k-fold cross-validation, with three repeats and 10 folds. We will report the mean and standard deviation of the accuracy of the model across all repeats and folds.

# %%
#Here, we have to be careful with the model section, from preovious sections we know which hyperparameters to tune
### So in this case, the model would be selecting the features which it considers more important
#based on the previous hyperparameters


#We choos the estimator and the features to select
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=3) 

#We define the model, with previous hyperparameters selected
model = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')

pipeline = Pipeline(steps=[('s',rfe),('m',model)])
# evaluate model
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
# report performance
print('Accuracy: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
# Out:
# Accuracy: 0.768 (0.006)

# %% [markdown]
# # Explore Number of Features
#
# An important hyperparameter for the RFE algorithm is the number of features to select.
#
# In the previous section, we used an arbitrary number of selected features, five, which matches the number of informative features in the synthetic dataset. In practice, we cannot know the best number of features to select with RFE; instead, it is good practice to test different values.
#
# The example below demonstrates selecting different numbers of features from 2 to 10 on the synthetic binary classification dataset.

# %%
# get a list of models to evaluate
def get_models():
    models = dict()
    for i in range(2, 10):
        rfe = RFE(estimator=DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced'), n_features_to_select=i)
        model = DecisionTreeClassifier(criterion = 'entropy', max_depth=8, class_weight='balanced')
        models[str(i)] = Pipeline(steps=[('s',rfe),('m',model)])
    return models

# %%
# evaluate a give model using cross-validation
def evaluate_model(model, X, y):
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
    return scores

# %%
# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
    scores = evaluate_model(model, X_train, y_train)
    results.append(scores)
    names.append(name)
    print('>%s %.3f (%.3f)' % (name, np.mean(scores), np.std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.show()
# Out:
# >3 0.769 (0.006)
# >2 0.766 (0.006)
# >5 0.768 (0.007)
# >4 0.769 (0.007)
# >7 0.769 (0.005)
# >6 0.768 (0.006)
# >9 0.768 (0.005)
# >8 0.769 (0.005)

# %% [markdown]
# # Which Features Were Selected
#
# When using RFE, we may be interested to know which features were selected and which were removed.
#
# This can be achieved by reviewing the attributes of the fit RFE object (or fit RFECV object). The “support_” attribute reports true or false as to which features in order of column index were included and the “ranking_” attribute reports the relative ranking of features in the same order.
#
# The example below fits an RFE model on the whole dataset and selects five features, then reports each feature column index (0 to 9), whether it was selected or not (True or False), and the relative feature ranking.

# %%
# define RFE
rfe = RFE(estimator=DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced'), n_features_to_select=3)
# fit RFE
rfe.fit(X_train, y_train)
# summarize all features
for i in range(X.shape[1]):
	print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected False, Rank: 8.000
# Column: 1, Selected False, Rank: 3.000
# Column: 2, Selected False, Rank: 4.000
# Column: 3, Selected True, Rank: 1.000
# Column: 4, Selected True, Rank: 1.000
# Column: 5, Selected False, Rank: 6.000
# Column: 6, Selected True, Rank: 1.000
# Column: 7, Selected False, Rank: 7.000
# Column: 8, Selected False, Rank: 2.000
# Column: 9, Selected False, Rank: 5.000

# %%
# define RFE
rfe = RFE(estimator=DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced'), n_features_to_select=4)
# fit RFE
rfe.fit(X_train, y_train)
# summarize all features
for i in range(X.shape[1]):
	print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected False, Rank: 7.000
# Column: 1, Selected False, Rank: 2.000
# Column: 2, Selected False, Rank: 4.000
# Column: 3, Selected True, Rank: 1.000
# Column: 4, Selected True, Rank: 1.000
# Column: 5, Selected False, Rank: 5.000
# Column: 6, Selected True, Rank: 1.000
# Column: 7, Selected False, Rank: 6.000
# Column: 8, Selected True, Rank: 1.000
# Column: 9, Selected False, Rank: 3.000

# %%
# define RFE
rfe = RFE(estimator=DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced'), n_features_to_select=7)
# fit RFE
rfe.fit(X_train, y_train)
# summarize all features
for i in range(X.shape[1]):
	print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected False, Rank: 4.000
# Column: 1, Selected True, Rank: 1.000
# Column: 2, Selected True, Rank: 1.000
# Column: 3, Selected True, Rank: 1.000
# Column: 4, Selected True, Rank: 1.000
# Column: 5, Selected False, Rank: 2.000
# Column: 6, Selected True, Rank: 1.000
# Column: 7, Selected False, Rank: 3.000
# Column: 8, Selected True, Rank: 1.000
# Column: 9, Selected True, Rank: 1.000

# %%
# define RFE
rfe = RFE(estimator=DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced'), n_features_to_select=8)
# fit RFE
rfe.fit(X_train, y_train)
# summarize all features
for i in range(X.shape[1]):
	print('Column: %d, Selected %s, Rank: %.3f' % (i, rfe.support_[i], rfe.ranking_[i]))
# Out:
# Column: 0, Selected False, Rank: 3.000
# Column: 1, Selected True, Rank: 1.000
# Column: 2, Selected True, Rank: 1.000
# Column: 3, Selected True, Rank: 1.000
# Column: 4, Selected True, Rank: 1.000
# Column: 5, Selected True, Rank: 1.000
# Column: 6, Selected True, Rank: 1.000
# Column: 7, Selected False, Rank: 2.000
# Column: 8, Selected True, Rank: 1.000
# Column: 9, Selected True, Rank: 1.000

# %% [markdown]
# # Now see the performance for each selected features, for both raw and scaled data

# %%
### RAW DATA, first 3 features, 4, 5, 7

X1_raw = shuffle_df.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr9', 'dr10','labels'], axis = 1)
y1_raw = shuffle_df.labels
X1_train_raw = train_set.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr9', 'dr10','labels'], axis = 1)
X1_test_raw = test_set.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr9', 'dr10','labels'], axis= 1)
y1_train_raw = train_set.labels
y1_test_raw = test_set.labels

#### SCALED DATA, first TREE features, 4, 5, 7

X1scaled = shuffled_scaled.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr9', 'dr10','labels'], axis = 1)
y1scaled = shuffled_scaled.labels
#yscaled_model = shuffled_dfr.Model
#ymodel = copy1.Model
X1_train_scaled = train_set1.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr9', 'dr10','labels'], axis = 1)
X1_test_scaled = test_set1.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr9', 'dr10','labels'], axis= 1)
y1_trainl_scaled = train_set1.labels
y1_testl_scaled = test_set1.labels


### RAW DATA, first 4 features, 4, 5, 7, 9

X2_raw = shuffle_df.drop(['dr1', 'dr2', 'dr3', 'dr6','dr8', 'dr10','labels'], axis = 1)
y2_raw = shuffle_df.labels
X2_train_raw = train_set.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr10','labels'], axis = 1)
X2_test_raw = test_set.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr10','labels'], axis= 1)
y2_train_raw = train_set.labels
y2_test_raw = test_set.labels

#### SCALED DATA, first 4 features, 4, 5, 7, 9

X2scaled = shuffled_scaled.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr10','labels'], axis = 1)
y2scaled = shuffled_scaled.labels
#yscaled_model = shuffled_dfr.Model
#ymodel = copy1.Model
X2_train_scaled = train_set1.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr10','labels'], axis = 1)
X2_test_scaled = test_set1.drop(['dr1', 'dr2', 'dr3', 'dr6', 'dr8', 'dr10','labels'], axis= 1)
y2_trainl_scaled = train_set1.labels
y2_testl_scaled = test_set1.labels

### RAW DATA, first 7 features, 2, 3, 4, 5, 7, 9, 10

X3_raw = shuffle_df.drop(['dr1', 'dr6', 'dr8','labels'], axis = 1)
y3_raw = shuffle_df.labels
X3_train_raw = train_set.drop(['dr1', 'dr6', 'dr8','labels'], axis = 1)
X3_test_raw = test_set.drop(['dr1', 'dr6', 'dr8','labels'], axis= 1)
y3_train_raw = train_set.labels
y3_test_raw = test_set.labels

#### SCALED DATA, first 7 features, 2, 3,4, 5, 7, 9, 10

X3scaled = shuffled_scaled.drop(['dr1', 'dr6', 'dr8','labels'], axis = 1)
y3scaled = shuffled_scaled.labels
#yscaled_model = shuffled_dfr.Model
#ymodel = copy1.Model
X3_train_scaled = train_set1.drop(['dr1', 'dr6', 'dr8','labels'], axis = 1)
X3_test_scaled = test_set1.drop(['dr1', 'dr6', 'dr8','labels'], axis= 1)
y3_trainl_scaled = train_set1.labels
y3_testl_scaled = test_set1.labels

### RAW DATA, first 8 features, 2, 3, 4, 5, 7,, 8, 9, 10

X4_raw = shuffle_df.drop(['dr1', 'dr6','labels'], axis = 1)
y4_raw = shuffle_df.labels
X4_train_raw = train_set.drop(['dr1','dr6','labels'], axis = 1)
X4_test_raw = test_set.drop(['dr1', 'dr6','labels'], axis= 1)
y4_train_raw = train_set.labels
y4_test_raw = test_set.labels

#### SCALED DATA, first 8 features, 2, 3, 4, 5, 7, 8, 9, 10

X4scaled = shuffled_scaled.drop(['dr1', 'dr6','labels'], axis = 1)
y4scaled = shuffled_scaled.labels
#yscaled_model = shuffled_dfr.Model
#ymodel = copy1.Model
X4_train_scaled = train_set1.drop(['dr1', 'dr6','labels'], axis = 1)
X4_test_scaled = test_set1.drop(['dr1', 'dr6','labels'], axis= 1)
y4_trainl_scaled = train_set1.labels
y4_testl_scaled = test_set1.labels

# %% [markdown]
# # DECISION TREES FOR RAW AND SCALED DATA

# %%
dt1_raw = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt1_raw = dt1.fit(X1_train_raw, y1_train_raw)
#Predict the response for test dataset
y1_pred_raw = dt1_raw.predict(X1_test_raw)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on first 3 selected features, dr4, dr5, dr7, raw data\n')
print("Accuracy:", metrics.accuracy_score(y1_test_raw, y1_pred_raw))
for i, score_tree in enumerate(cross_val_score(dt1_raw, X1_raw, y1_raw, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt1_raw, X1_raw ,y1_raw, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

dt1_scaled = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt1_scaled = dt1_scaled.fit(X1_train_scaled, y1_trainl_scaled)
#Predict the response for test dataset
y1_pred_scaled = dt1_scaled.predict(X1_test_scaled)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on selected scaled features, dr4, dr5, dr7 \n')
print("Accuracy:", metrics.accuracy_score(y1_testl_scaled, y1_pred_scaled))
for i, score_tree in enumerate(cross_val_score(dt1_scaled, X1scaled, y1scaled, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt1_scaled, X1scaled ,y1scaled, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)


###############################################################################################
###############################################################################################


dt2_raw = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt2_raw = dt2_raw.fit(X2_train_raw, y2_train_raw)
#Predict the response for test dataset
y2_pred_raw = dt2_raw.predict(X2_test_raw)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on first 4 selected features, dr2, dr3, dr4, dr5, dr7, dr9 raw data\n')
print("Accuracy:", metrics.accuracy_score(y2_test_raw, y2_pred_raw))
for i, score_tree in enumerate(cross_val_score(dt2_raw, X2_raw, y2_raw, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt2_raw, X2_raw ,y2_raw, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

dt2_scaled = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt2_scaled = dt2_scaled.fit(X2_train_scaled, y2_trainl_scaled)
#Predict the response for test dataset
y2_pred_scaled = dt2_scaled.predict(X2_test_scaled)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on selected scaled features, dr4, dr5, dr7, dr8 \n')
print("Accuracy:", metrics.accuracy_score(y2_testl_scaled, y2_pred_scaled))
for i, score_tree in enumerate(cross_val_score(dt2_scaled, X2scaled, y2scaled, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt2_scaled, X2scaled ,y2scaled, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)


###############################################################################################
###############################################################################################


dt3_raw = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt3_raw = dt3_raw.fit(X3_train_raw, y3_train_raw)
#Predict the response for test dataset
y3_pred_raw = dt3_raw.predict(X3_test_raw)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on first 7 selected features,dr2, dr3, dr4, dr5, dr7, dr9, dr10 raw data\n')
print("Accuracy:", metrics.accuracy_score(y3_test_raw, y3_pred_raw))
for i, score_tree in enumerate(cross_val_score(dt3_raw, X3_raw, y3_raw, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt3_raw, X3_raw ,y3_raw, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

dt3_scaled = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt3_scaled = dt3_scaled.fit(X3_train_scaled, y3_trainl_scaled)
#Predict the response for test dataset
y3_pred_scaled = dt3_scaled.predict(X3_test_scaled)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on selected scaled features,dr2, dr3, dr4, dr5, dr7, dr9, dr10 \n')
print("Accuracy:", metrics.accuracy_score(y3_testl_scaled, y3_pred_scaled))
for i, score_tree in enumerate(cross_val_score(dt3_scaled, X3scaled, y3scaled, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt3_scaled, X3scaled ,y3scaled, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

###############################################################################################
###############################################################################################

dt4_raw = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt4_raw = dt4_raw.fit(X4_train_raw, y4_train_raw)
#Predict the response for test dataset
y4_pred_raw = dt4_raw.predict(X4_test_raw)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on 8 selected features,dr2, dr3, dr4, dr5, dr7,, dr8, dr9, dr10 raw data\n')
print("Accuracy:", metrics.accuracy_score(y4_test_raw, y4_pred_raw))
for i, score_tree in enumerate(cross_val_score(dt4_raw, X4_raw, y4_raw, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt4_raw, X4_raw ,y4_raw, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)

dt4_scaled = DecisionTreeClassifier(criterion='entropy', max_depth=8, class_weight='balanced')
dt4_scaled = dt4_scaled.fit(X4_train_scaled, y4_trainl_scaled)
#Predict the response for test dataset
y4_pred_scaled = dt4_scaled.predict(X4_test_scaled)
#Model accuracy, how often is the classifier correct
#print(cross_val_score(dt1, X1.reshape(-1,1), y, cv=6))
print('Training and testing on  8 selected scaled features,dr2, dr3, dr4, dr5, dr7,dr8, dr9, dr10 \n')
print("Accuracy:", metrics.accuracy_score(y4_testl_scaled, y4_pred_scaled))
for i, score_tree in enumerate(cross_val_score(dt4_scaled, X4scaled, y4scaled, cv = 10)):
    print('Decision tree accuracy for the %d score: %0.2f' % (i, score_tree))
score_tree=cross_val_score(dt4_scaled, X4scaled ,y4scaled, cv=10)
#score_tree
cv_scores = []
print("Decision Tree Accuracy: %0.2f (+/- %0.2f)" % (score_tree.mean(), score_tree.std() * 2 ))
cv_score = score_tree.mean()
cv_scores.append(cv_score)
# Out:
# Training and testing on first 3 selected features, dr4, dr5, dr7, raw data
#
# ('Accuracy:', 0.7763005780346821)
# Decision tree accuracy for the 0 score: 0.77
# Decision tree accuracy for the 1 score: 0.78
# Decision tree accuracy for the 2 score: 0.77
# Decision tree accuracy for the 3 score: 0.78
# Decision tree accuracy for the 4 score: 0.76
# Decision tree accuracy for the 5 score: 0.77
# Decision tree accuracy for the 6 score: 0.77
# Decision tree accuracy for the 7 score: 0.76
# Decision tree accuracy for the 8 score: 0.77
# Decision tree accuracy for the 9 score: 0.77
# Decision Tree Accuracy: 0.77 (+/- 0.01)
# Training and testing on selected scaled features, dr4, dr5, dr7
#
# ('Accuracy:', 0.7713872832369942)
# Decision tree accuracy for the 0 score: 0.78
# Decision tree accuracy for the 1 score: 0.77
# Decision tree accuracy for the 2 score: 0.77
# Decision tree accuracy for the 3 score: 0.78
# Decision tree accuracy for the 4 score: 0.77
# ...
